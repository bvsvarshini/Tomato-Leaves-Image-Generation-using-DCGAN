# %% [markdown]
# <a href="https://colab.research.google.com/github/bvsvarshini/Tomato-Leaves-Image-Generation-using-DCGAN/blob/main/healthy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import requirement libraries and tools
from tensorflow import keras
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Conv2DTranspose, Reshape, BatchNormalization, Dropout, Input, ReLU, LeakyReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from PIL import Image

import warnings
warnings.filterwarnings('ignore')

# %%
import zipfile
import os

# Path to the uploaded zip file
zip_path = '/content/healthy.zip'
# Directory where the zip will be extracted
extraction_path = '/content/healthy/'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

# Verify extraction
print("Files extracted:")
print(os.listdir(extraction_path))
# Out:
# Files extracted:
# ['healthy']

# %%
data_dir = extraction_path

# Example: List files in the data_dir
import os
print(os.listdir(data_dir))
# Out:
# ['healthy']

# %%
img_width, img_height = 256, 256
batchsize = 32

train = keras. utils.image_dataset_from_directory(
    directory='healthy',
    batch_size = batchsize,
    image_size = (img_width, img_height))
# Out:
# Found 1591 files belonging to 1 classes.

# %%
import tensorflow as tf

# Define the path to the extracted images
data_dir = extraction_path

# Load the dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    image_size=(img_width, img_height),
    batch_size=batchsize,
    label_mode=None  # or 'int'/'categorical' depending on your labels
)
# Out:
# Found 1591 files belonging to 1 classes.

# %%
data_iterator = train.as_numpy_iterator()
batch = data_iterator.next()
fig, ax = plt.subplots(ncols=4, figsize=(10,10))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Generating Augmented Batches of Images using ImageDataGenerator
DIR = 'healthy' #path

# Create an ImageDataGenerator object with data augmentation options for image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip = True)

train_generator = train_datagen.flow_from_directory(
        DIR,
        target_size = (64, 64),
        batch_size = batchsize,
        class_mode = None)

#train_generator[0]
# Out:
# Found 1591 images belonging to 1 classes.

# %%
from tensorflow.keras.layers import Conv2DTranspose, Dense, Reshape
from tensorflow.keras.models import Sequential
import tensorflow.keras as keras

KI = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
input_dim = 300

def Generator_Model():
    Generator = Sequential()

    # Random noise
    Generator.add(Dense(8 * 8 * 512, input_dim=input_dim))
    Generator.add(keras.layers.Activation('relu'))  # Use 'relu' as a string
    # Convert 1D to 3D
    Generator.add(Reshape((8, 8, 512)))
    # Upsample
    Generator.add(Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2D(3, (4, 4), padding='same', activation='sigmoid'))

    return Generator

generator = Generator_Model()
generator.summary()
# Visualize Layers of generator
keras.utils.plot_model(generator, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32768)             9863168
#
#  activation (Activation)     (None, 32768)             0
#
#  reshape (Reshape)           (None, 8, 8, 512)         0
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 256)       2097408
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 128)       524416
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 64)        131136
#  Transpose)
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         3075
#
# =================================================================
# Total params: 12619203 (48.14 MB)
# Trainable params: 12619203 (48.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LeakyReLU
from tensorflow.keras.models import Sequential

def Discriminator_Model():
    input_shape = (64, 64, 3)

    # Create a Sequential model
    discriminator = Sequential()
    discriminator.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(128, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(256, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Flatten())
    discriminator.add(Dense(256))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(Dense(1, activation='sigmoid'))

    return discriminator

# Training The CNN
discriminator = Discriminator_Model()
discriminator.summary()
# Visualize Layers of discriminator
import tensorflow.keras as keras
keras.utils.plot_model(discriminator, show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 62, 62, 64)        1792
#
#  leaky_re_lu (LeakyReLU)     (None, 62, 62, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 29, 29, 128)       73856
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 29, 29, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 12, 12, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense_1 (Dense)             (None, 256)               2359552
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2730625 (10.42 MB)
# Trainable params: 2730625 (10.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# DCGAN Model Training Step with Discriminator and Generator

class DCGAN(keras.Model):
    def __init__(self, generator, discriminator, latent_dim = input_dim):
        super().__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_loss_metric = keras.metrics.Mean(name='d_loss')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_loss_metric]

    def compile(self, g_optimizer, d_optimizer, loss_fn):
        super(DCGAN, self).compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.loss_fn = loss_fn

    def train_step(self, real_images):
        # get batch size from the data
        batch_size = tf.shape(real_images)[0]
        # generate random noise
        random_noise = tf.random.normal(shape=(batch_size, self.latent_dim))

        # train the discriminator with real (1) and fake (0) images
        with tf.GradientTape() as tape:
            # compute loss on real images
            pred_real = self.discriminator(real_images, training=True)
            # generate real image labels
            real_labels = tf.ones((batch_size, 1))
            # label smoothing
            real_labels += 0.05 * tf.random.uniform(tf.shape(real_labels))
            d_loss_real = self.loss_fn(real_labels, pred_real)

            # compute loss on fake images
            fake_images = self.generator(random_noise)
            pred_fake = self.discriminator(fake_images, training=True)
            # generate fake labels
            fake_labels = tf.zeros((batch_size, 1))
            d_loss_fake = self.loss_fn(fake_labels, pred_fake)

            # total discriminator loss
            d_loss = (d_loss_real + d_loss_fake) / 2
        # compute discriminator gradients
        gradients = tape.gradient(d_loss, self.discriminator.trainable_variables)
        # update the gradients
        self.d_optimizer.apply_gradients(zip(gradients, self.discriminator.trainable_variables))


        # train the generator model
        labels = tf.ones((batch_size, 1))
        # generator want discriminator to think that fake images are real
        with tf.GradientTape() as tape:
            # generate fake images from generator
            fake_images = self.generator(random_noise, training=True)
            # classify images as real or fake
            pred_fake = self.discriminator(fake_images, training=True)
            # compute loss
            g_loss = self.loss_fn(labels, pred_fake)

        # compute gradients
        gradients = tape.gradient(g_loss, self.generator.trainable_variables)
        # update the gradients
        self.g_optimizer.apply_gradients(zip(gradients, self.generator.trainable_variables))

        # update states for both models
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {'d_loss': self.d_loss_metric.result(), 'g_loss': self.g_loss_metric.result()}

# %%
import os

class DCGANMonitor(keras.callbacks.Callback):
    def __init__(self, num_imgs=25, latent_dim = input_dim):
        self.num_imgs = num_imgs
        self.latent_dim = latent_dim
        # Create random noise for generating images
        self.noise = tf.random.normal([25, latent_dim])
        # Create a directory to save generated images if it doesn't exist
        if not os.path.exists('generated_images'):
            os.makedirs('generated_images')

    def on_epoch_end(self, epoch, logs=None):
        # Generate the image from noise
        g_img = self.model.generator(self.noise)
        # Denormalize the image
        g_img = (g_img * 255).numpy().astype(np.uint8)

        for i in range(g_img.shape[0]):
            # Convert generated images to PIL Image format
            img = Image.fromarray(g_img[i])
            # Save the image to the local folder
            img.save(f'generated_images/image_epoch_{epoch+1}_img_{i+1}.png')

    def on_train_end(self, logs=None):
        self.model.generator.save('DCGEN.h5')

# %%
# Training DCGAN on Image Dataset for 40 Epochs

epochs = 200
lr_g =0.0003
lr_d = 0.0001
beta = 0.5
latent_dim = 300

dcgan = DCGAN(generator=generator, discriminator=discriminator, latent_dim = latent_dim )
dcgan.compile(g_optimizer = Adam (learning_rate= lr_g, beta_1= beta), d_optimizer= Adam (learning_rate = lr_g , beta_1= beta), loss_fn = BinaryCrossentropy())

# Fit the model and save the history
history = dcgan.fit(train_generator, epochs=epochs, callbacks=[DCGANMonitor()])
# Out:
# Epoch 1/200
# 50/50 [==============================] - 22s 396ms/step - d_loss: 0.5883 - g_loss: 1.1852
# Epoch 2/200
# 50/50 [==============================] - 19s 382ms/step - d_loss: 0.3485 - g_loss: 1.7302
# Epoch 3/200
# 50/50 [==============================] - 19s 383ms/step - d_loss: 0.5539 - g_loss: 1.5650
# Epoch 4/200
# 50/50 [==============================] - 20s 392ms/step - d_loss: 0.4429 - g_loss: 1.5796
# Epoch 5/200
# 50/50 [==============================] - 19s 385ms/step - d_loss: 0.4791 - g_loss: 1.5414
# Epoch 6/200
# 50/50 [==============================] - 19s 389ms/step - d_loss: 0.5888 - g_loss: 1.7088
# Epoch 7/200
# 50/50 [==============================] - 19s 383ms/step - d_loss: 0.5016 - g_loss: 1.2840
# Epoch 8/200
# 50/50 [==============================] - 19s 382ms/step - d_loss: 0.4067 - g_loss: 1.4340
# Epoch 9/200
# 50/50 [==============================] - 19s 384ms/step - d_loss: 0.4878 - g_loss: 1.3641
# Epoch 10/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.5139 - g_loss: 1.3729
# Epoch 11/200
# 50/50 [==============================] - 19s 379ms/step - d_loss: 0.4245 - g_loss: 1.3202
# Epoch 12/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.4865 - g_loss: 1.2419
# Epoch 13/200
# 50/50 [==============================] - 18s 370ms/step - d_loss: 0.4770 - g_loss: 1.2714
# Epoch 14/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4786 - g_loss: 1.2190
# Epoch 15/200
# 50/50 [==============================] - 19s 378ms/step - d_loss: 0.4931 - g_loss: 1.3275
# Epoch 16/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4627 - g_loss: 1.2853
# Epoch 17/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.4659 - g_loss: 1.2863
# Epoch 18/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4871 - g_loss: 1.2802
# Epoch 19/200
# 50/50 [==============================] - 19s 381ms/step - d_loss: 0.4695 - g_loss: 1.2521
# Epoch 20/200
# 50/50 [==============================] - 19s 384ms/step - d_loss: 0.4468 - g_loss: 1.3289
# Epoch 21/200
# 50/50 [==============================] - 19s 379ms/step - d_loss: 0.4319 - g_loss: 1.2644
# Epoch 22/200
# 50/50 [==============================] - 19s 383ms/step - d_loss: 0.4291 - g_loss: 1.3507
# Epoch 23/200
# 50/50 [==============================] - 19s 385ms/step - d_loss: 0.4203 - g_loss: 1.3510
# Epoch 24/200
# 50/50 [==============================] - 19s 382ms/step - d_loss: 0.4701 - g_loss: 1.3427
# Epoch 25/200
# 50/50 [==============================] - 19s 382ms/step - d_loss: 0.4118 - g_loss: 1.3339
# Epoch 26/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4692 - g_loss: 1.3128
# Epoch 27/200
# 50/50 [==============================] - 18s 362ms/step - d_loss: 0.4256 - g_loss: 1.3313
# Epoch 28/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.4402 - g_loss: 1.3421
# Epoch 29/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.4191 - g_loss: 1.3758
# Epoch 30/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.3941 - g_loss: 1.3778
# Epoch 31/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.3840 - g_loss: 1.3696
# Epoch 32/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4106 - g_loss: 1.4031
# Epoch 33/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.4019 - g_loss: 1.4224
# Epoch 34/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.4104 - g_loss: 1.4143
# Epoch 35/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.3861 - g_loss: 1.4654
# Epoch 36/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.3824 - g_loss: 1.4182
# Epoch 37/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.3643 - g_loss: 1.4013
# Epoch 38/200
# 50/50 [==============================] - 19s 369ms/step - d_loss: 0.3766 - g_loss: 1.4566
# Epoch 39/200
# 50/50 [==============================] - 19s 380ms/step - d_loss: 0.4021 - g_loss: 1.4665
# Epoch 40/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4112 - g_loss: 1.4106
# Epoch 41/200
# 50/50 [==============================] - 19s 381ms/step - d_loss: 0.4003 - g_loss: 1.4337
# Epoch 42/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.3859 - g_loss: 1.4098
# Epoch 43/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.3966 - g_loss: 1.4560
# Epoch 44/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4036 - g_loss: 1.3986
# Epoch 45/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.3684 - g_loss: 1.3714
# Epoch 46/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.3559 - g_loss: 1.5067
# Epoch 47/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.4217 - g_loss: 1.4274
# Epoch 48/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.3280 - g_loss: 1.4822
# Epoch 49/200
# 50/50 [==============================] - 19s 383ms/step - d_loss: 0.4075 - g_loss: 1.4380
# Epoch 50/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.2730 - g_loss: 1.4224
# Epoch 51/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.3820 - g_loss: 1.5365
# Epoch 52/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.2661 - g_loss: 1.5098
# Epoch 53/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.6230 - g_loss: 1.7527
# Epoch 54/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.5373 - g_loss: 1.2383
# Epoch 55/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.6071 - g_loss: 1.1974
# Epoch 56/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.5358 - g_loss: 1.1931
# Epoch 57/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.5607 - g_loss: 1.2309
# Epoch 58/200
# 50/50 [==============================] - 19s 375ms/step - d_loss: 0.4447 - g_loss: 1.4328
# Epoch 59/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.4460 - g_loss: 1.3958
# Epoch 60/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.4983 - g_loss: 1.2657
# Epoch 61/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.3997 - g_loss: 1.3819
# Epoch 62/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4975 - g_loss: 1.3181
# Epoch 63/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.3016 - g_loss: 1.3478
# Epoch 64/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.4030 - g_loss: 1.4014
# Epoch 65/200
# 50/50 [==============================] - 19s 375ms/step - d_loss: 0.3116 - g_loss: 1.3857
# Epoch 66/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.2324 - g_loss: 1.4865
# Epoch 67/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.3156 - g_loss: 1.5649
# Epoch 68/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.8790 - g_loss: 1.6347
# Epoch 69/200
# 50/50 [==============================] - 19s 375ms/step - d_loss: 0.6080 - g_loss: 1.1189
# Epoch 70/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.5910 - g_loss: 1.0650
# Epoch 71/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.5230 - g_loss: 1.2124
# Epoch 72/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.4880 - g_loss: 1.1534
# Epoch 73/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.5043 - g_loss: 1.1739
# Epoch 74/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4814 - g_loss: 1.1625
# Epoch 75/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.4776 - g_loss: 1.2026
# Epoch 76/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4333 - g_loss: 1.2612
# Epoch 77/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.4219 - g_loss: 1.8114
# Epoch 78/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4030 - g_loss: 1.3288
# Epoch 79/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.4896 - g_loss: 1.3177
# Epoch 80/200
# 50/50 [==============================] - 18s 365ms/step - d_loss: 0.4292 - g_loss: 1.2247
# Epoch 81/200
# 50/50 [==============================] - 19s 375ms/step - d_loss: 0.4033 - g_loss: 1.3273
# Epoch 82/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.4166 - g_loss: 1.2793
# Epoch 83/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.3976 - g_loss: 1.3850
# Epoch 84/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: 0.4121 - g_loss: 1.3689
# Epoch 85/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.3772 - g_loss: 1.3331
# Epoch 86/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: 0.3495 - g_loss: 1.4015
# Epoch 87/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.3062 - g_loss: 1.4065
# Epoch 88/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.2784 - g_loss: 1.5931
# Epoch 89/200
# 50/50 [==============================] - 19s 372ms/step - d_loss: -0.1182 - g_loss: 2.0124
# Epoch 90/200
# 50/50 [==============================] - 19s 375ms/step - d_loss: 1.0232 - g_loss: 1.7825
# Epoch 91/200
# 50/50 [==============================] - 19s 378ms/step - d_loss: 0.5648 - g_loss: 1.2839
# Epoch 92/200
# 50/50 [==============================] - 19s 378ms/step - d_loss: 0.4814 - g_loss: 1.1991
# Epoch 93/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.4605 - g_loss: 1.2427
# Epoch 94/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.5779 - g_loss: 1.2676
# Epoch 95/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.5344 - g_loss: 1.1474
# Epoch 96/200
# 50/50 [==============================] - 18s 362ms/step - d_loss: 0.4945 - g_loss: 1.1264
# Epoch 97/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4984 - g_loss: 1.1592
# Epoch 98/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4557 - g_loss: 1.1969
# Epoch 99/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.4463 - g_loss: 1.2735
# Epoch 100/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: 0.4255 - g_loss: 1.2599
# Epoch 101/200
# 50/50 [==============================] - 19s 369ms/step - d_loss: 0.4699 - g_loss: 1.3023
# Epoch 102/200
# 50/50 [==============================] - 18s 370ms/step - d_loss: 0.3971 - g_loss: 1.2861
# Epoch 103/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.4754 - g_loss: 1.5387
# Epoch 104/200
# 50/50 [==============================] - 19s 369ms/step - d_loss: 0.3182 - g_loss: 1.4438
# Epoch 105/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.3634 - g_loss: 1.4632
# Epoch 106/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.3103 - g_loss: 1.3764
# Epoch 107/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.2997 - g_loss: 1.3837
# Epoch 108/200
# 50/50 [==============================] - 19s 369ms/step - d_loss: 0.2040 - g_loss: 1.5825
# Epoch 109/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.4080 - g_loss: 1.4113
# Epoch 110/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.2861 - g_loss: 1.4937
# Epoch 111/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.2922 - g_loss: 1.4446
# Epoch 112/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.2697 - g_loss: 1.4137
# Epoch 113/200
# 50/50 [==============================] - 19s 374ms/step - d_loss: 0.0516 - g_loss: 1.8053
# Epoch 114/200
# 50/50 [==============================] - 19s 383ms/step - d_loss: 0.1551 - g_loss: 1.8418
# Epoch 115/200
# 50/50 [==============================] - 19s 378ms/step - d_loss: 0.5722 - g_loss: 1.8041
# Epoch 116/200
# 50/50 [==============================] - 19s 377ms/step - d_loss: 0.5314 - g_loss: 1.5789
# Epoch 117/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 0.5679 - g_loss: 1.2551
# Epoch 118/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.4620 - g_loss: 1.2281
# Epoch 119/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.5257 - g_loss: 1.6238
# Epoch 120/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.4766 - g_loss: 2.2653
# Epoch 121/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.3538 - g_loss: 1.5259
# Epoch 122/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.0036 - g_loss: 1.3881
# Epoch 123/200
# 50/50 [==============================] - 19s 371ms/step - d_loss: 0.1942 - g_loss: 1.5354
# Epoch 124/200
# 50/50 [==============================] - 18s 361ms/step - d_loss: -0.1942 - g_loss: 1.5314
# Epoch 125/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.5338 - g_loss: 2.4604
# Epoch 126/200
# 50/50 [==============================] - 19s 370ms/step - d_loss: 0.1561 - g_loss: 1.9158
# Epoch 127/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.6679 - g_loss: 1.6163
# Epoch 128/200
# 50/50 [==============================] - 18s 360ms/step - d_loss: 0.5647 - g_loss: 1.4394
# Epoch 129/200
# 50/50 [==============================] - 18s 362ms/step - d_loss: 0.3275 - g_loss: 1.3543
# Epoch 130/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: 0.2329 - g_loss: 1.6157
# Epoch 131/200
# 50/50 [==============================] - 18s 361ms/step - d_loss: -0.7744 - g_loss: 1.8559
# Epoch 132/200
# 50/50 [==============================] - 18s 359ms/step - d_loss: -0.9474 - g_loss: 2.2362
# Epoch 133/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: 1.8302 - g_loss: 3.3552
# Epoch 134/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: 0.7548 - g_loss: 1.7950
# Epoch 135/200
# 50/50 [==============================] - 18s 360ms/step - d_loss: 0.5987 - g_loss: 1.3227
# Epoch 136/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.5150 - g_loss: 1.2409
# Epoch 137/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.4689 - g_loss: 1.2831
# Epoch 138/200
# 50/50 [==============================] - 18s 365ms/step - d_loss: 0.5084 - g_loss: 1.2257
# Epoch 139/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: 0.6590 - g_loss: 1.7365
# Epoch 140/200
# 50/50 [==============================] - 18s 365ms/step - d_loss: 0.3522 - g_loss: 1.4841
# Epoch 141/200
# 50/50 [==============================] - 18s 365ms/step - d_loss: 0.3494 - g_loss: 1.3555
# Epoch 142/200
# 50/50 [==============================] - 18s 362ms/step - d_loss: 0.1392 - g_loss: 1.3761
# Epoch 143/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: -0.3664 - g_loss: 1.5054
# Epoch 144/200
# 50/50 [==============================] - 18s 363ms/step - d_loss: -1.3506 - g_loss: 1.5250
# Epoch 145/200
# 50/50 [==============================] - 18s 368ms/step - d_loss: -0.3798 - g_loss: 2.4021
# Epoch 146/200
# 50/50 [==============================] - 18s 364ms/step - d_loss: -2.4797 - g_loss: 2.6077
# Epoch 147/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 5.3138 - g_loss: 3.2651
# Epoch 148/200
# 50/50 [==============================] - 18s 365ms/step - d_loss: 0.4338 - g_loss: 2.0599
# Epoch 149/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 1.4377 - g_loss: 2.3236
# Epoch 150/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.6856 - g_loss: 2.1258
# Epoch 151/200
# 50/50 [==============================] - 18s 361ms/step - d_loss: 0.3990 - g_loss: 1.3730
# Epoch 152/200
# 50/50 [==============================] - 18s 357ms/step - d_loss: 0.1368 - g_loss: 1.3987
# Epoch 153/200
# 50/50 [==============================] - 18s 366ms/step - d_loss: -1.6164 - g_loss: 1.7560
# Epoch 154/200
# 50/50 [==============================] - 18s 362ms/step - d_loss: 0.9353 - g_loss: 2.6277
# Epoch 155/200
# 50/50 [==============================] - 19s 376ms/step - d_loss: 1.1015 - g_loss: 2.2116
# Epoch 156/200
# 50/50 [==============================] - 18s 367ms/step - d_loss: 0.8885 - g_loss: 1.7066
# Epoch 157/200
# 50/50 [==============================] - 18s 369ms/step - d_loss: 0.5993 - g_loss: 1.4419
# Epoch 158/200
# 50/50 [==============================] - 18s 370ms/step - d_loss: 0.5046 - g_loss: 1.2272
# Epoch 159/200
# 50/50 [==============================] - 19s 373ms/step - d_loss: 0.5327 - g_loss: 1.2219
# Epoch 160/200
#  2/50 [>.............................] - ETA: 17s - d_loss: 0.4955 - g_loss: 0.8945

# %%
import os

plt.figure(figsize=(10, 10))

# Create a directory to save generated images if it doesn't exist
if not os.path.exists('generated_images'):
    os.makedirs('generated_images')

for i in range(36):
    plt.subplot(6, 6, i + 1)
    # Generate random noise for each image
    noise = tf.random.normal([1, 300])
    mg = dcgan.generator(noise)
    # Denormalize
    mg = (mg * 255).numpy().astype(np.uint8)

    image = Image.fromarray(mg[0])
    # Save the image to the local folder
    image.save(f'generated_images/image_{i+1}.png')

    plt.imshow(image)
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

# Function to create a figure for the losses
def create_loss_figure(d_loss_values, g_loss_values):
    plt.figure(figsize=(10, 6))
    plt.plot(d_loss_values, label='Discriminator Loss')
    plt.plot(g_loss_values, label='Generator Loss')
    plt.title('Generator and Discriminator Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Access the loss values from the history
d_loss_values = history.history['d_loss']
g_loss_values = history.history['g_loss']

# Call the create_loss_figure function with the loss values
create_loss_figure(d_loss_values, g_loss_values)

# %%
# !zip -r generated_images.zip generated_images/
from google.colab import files
files.download('generated_images.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: generated_images/image_epoch_155_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_21.png (deflated 0%)
#   adding: generated_images/image_epoch_24_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_22.png (deflated 0%)
#   adding: generated_images/image_epoch_125_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_5.png (stored 0%)
#   adding: generated_images/image_9.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_19.png (stored 0%)
#   adding: generated_images/image_26.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_7.png (deflated 0%)
#   adding: generated_images/image_epoch_63_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_3.png (deflated 0%)
#   adding: generated_images/image_epoch_38_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_23.png (stored 0%)
#   adding: generated_images/image_14.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_24.png (deflated 0%)
#   adding: generated_images/image_epoch_117_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_10.png (stored 0%)
#   adding: generated_images/image_30.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_18.png (deflated 0%)
#   adding: generated_images/image_epoch_155_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_21.png (stored 0%)
#   adding: generated_images/image_19.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_7.png (stored 0%)
# ...
#   adding: generated_images/image_epoch_155_img_7.png (stored 0%)
#   adding: generated_images/image_7.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_89_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_11.png (stored 0%)
#   adding: generated_images/image_3.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_19.png (deflated 0%)
#   adding: generated_images/image_epoch_15_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_12.png (stored 0%)
#   adding: generated_images/image_8.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_5.png (deflated 0%)
#   adding: generated_images/image_epoch_135_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_16.png (stored 0%)
