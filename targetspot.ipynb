# %% [markdown]
# <a href="https://colab.research.google.com/github/bvsvarshini/Tomato-Leaves-Image-Generation-using-DCGAN/blob/main/targetspot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import requirement libraries and tools
from tensorflow import keras
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Conv2DTranspose, Reshape, BatchNormalization, Dropout, Input, ReLU, LeakyReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from PIL import Image

import warnings
warnings.filterwarnings('ignore')

# %%
import zipfile
import os

# Path to the uploaded zip file
zip_path = '/content/targetspot.zip'
# Directory where the zip will be extracted
extraction_path = '/content/targetspot/'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

# Verify extraction
print("Files extracted:")
print(os.listdir(extraction_path))
# Out:
# Files extracted:
# ['targetspot']

# %%
data_dir = extraction_path

# Example: List files in the data_dir
import os
print(os.listdir(data_dir))
# Out:
# ['targetspot']

# %%
img_width, img_height = 256, 256
batchsize = 32

train = keras. utils.image_dataset_from_directory(
    directory='targetspot',
    batch_size = batchsize,
    image_size = (img_width, img_height))
# Out:
# Found 1404 files belonging to 1 classes.

# %%
import tensorflow as tf

# Define the path to the extracted images
data_dir = extraction_path

# Load the dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    image_size=(img_width, img_height),
    batch_size=batchsize,
    label_mode=None  # or 'int'/'categorical' depending on your labels
)
# Out:
# Found 1404 files.

# %%
data_iterator = train.as_numpy_iterator()
batch = data_iterator.next()
fig, ax = plt.subplots(ncols=4, figsize=(10,10))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Generating Augmented Batches of Images using ImageDataGenerator
DIR = 'targetspot' #path

# Create an ImageDataGenerator object with data augmentation options for image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip = True)

train_generator = train_datagen.flow_from_directory(
        DIR,
        target_size = (64, 64),
        batch_size = batchsize,
        class_mode = None)

#train_generator[0]
# Out:
# Found 1404 images belonging to 1 classes.

# %%
from tensorflow.keras.layers import Conv2DTranspose, Dense, Reshape
from tensorflow.keras.models import Sequential
import tensorflow.keras as keras

KI = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
input_dim = 300

def Generator_Model():
    Generator = Sequential()

    # Random noise
    Generator.add(Dense(8 * 8 * 512, input_dim=input_dim))
    Generator.add(keras.layers.Activation('relu'))  # Use 'relu' as a string
    # Convert 1D to 3D
    Generator.add(Reshape((8, 8, 512)))
    # Upsample
    Generator.add(Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2D(3, (4, 4), padding='same', activation='sigmoid'))

    return Generator

generator = Generator_Model()
generator.summary()
# Visualize Layers of generator
keras.utils.plot_model(generator, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32768)               │       9,863,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 16, 16, 256)         │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 32, 32, 128)         │         524,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 64, 64, 64)          │         131,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 64, 64, 3)           │           3,075 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,619,203 (48.14 MB)
#  Trainable params: 12,619,203 (48.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LeakyReLU
from tensorflow.keras.models import Sequential

def Discriminator_Model():
    input_shape = (64, 64, 3)

    # Create a Sequential model
    discriminator = Sequential()
    discriminator.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(128, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(256, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Flatten())
    discriminator.add(Dense(256))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(Dense(1, activation='sigmoid'))

    return discriminator

# Training The CNN
discriminator = Discriminator_Model()
discriminator.summary()
# Visualize Layers of discriminator
import tensorflow.keras as keras
keras.utils.plot_model(discriminator, show_shapes=True)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)                    │ (None, 62, 62, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 29, 29, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 29, 29, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │       2,359,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,730,625 (10.42 MB)
#  Trainable params: 2,730,625 (10.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# DCGAN Model Training Step with Discriminator and Generator

class DCGAN(keras.Model):
    def __init__(self, generator, discriminator, latent_dim = input_dim):
        super().__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_loss_metric = keras.metrics.Mean(name='d_loss')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_loss_metric]

    def compile(self, g_optimizer, d_optimizer, loss_fn):
        super(DCGAN, self).compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.loss_fn = loss_fn

    def train_step(self, real_images):
        # get batch size from the data
        batch_size = tf.shape(real_images)[0]
        # generate random noise
        random_noise = tf.random.normal(shape=(batch_size, self.latent_dim))

        # train the discriminator with real (1) and fake (0) images
        with tf.GradientTape() as tape:
            # compute loss on real images
            pred_real = self.discriminator(real_images, training=True)
            # generate real image labels
            real_labels = tf.ones((batch_size, 1))
            # label smoothing
            real_labels += 0.05 * tf.random.uniform(tf.shape(real_labels))
            d_loss_real = self.loss_fn(real_labels, pred_real)

            # compute loss on fake images
            fake_images = self.generator(random_noise)
            pred_fake = self.discriminator(fake_images, training=True)
            # generate fake labels
            fake_labels = tf.zeros((batch_size, 1))
            d_loss_fake = self.loss_fn(fake_labels, pred_fake)

            # total discriminator loss
            d_loss = (d_loss_real + d_loss_fake) / 2
        # compute discriminator gradients
        gradients = tape.gradient(d_loss, self.discriminator.trainable_variables)
        # update the gradients
        self.d_optimizer.apply_gradients(zip(gradients, self.discriminator.trainable_variables))


        # train the generator model
        labels = tf.ones((batch_size, 1))
        # generator want discriminator to think that fake images are real
        with tf.GradientTape() as tape:
            # generate fake images from generator
            fake_images = self.generator(random_noise, training=True)
            # classify images as real or fake
            pred_fake = self.discriminator(fake_images, training=True)
            # compute loss
            g_loss = self.loss_fn(labels, pred_fake)

        # compute gradients
        gradients = tape.gradient(g_loss, self.generator.trainable_variables)
        # update the gradients
        self.g_optimizer.apply_gradients(zip(gradients, self.generator.trainable_variables))

        # update states for both models
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {'d_loss': self.d_loss_metric.result(), 'g_loss': self.g_loss_metric.result()}

# %%
import os

class DCGANMonitor(keras.callbacks.Callback):
    def __init__(self, num_imgs=25, latent_dim = input_dim):
        self.num_imgs = num_imgs
        self.latent_dim = latent_dim
        # Create random noise for generating images
        self.noise = tf.random.normal([25, latent_dim])
        # Create a directory to save generated images if it doesn't exist
        if not os.path.exists('generated_images'):
            os.makedirs('generated_images')

    def on_epoch_end(self, epoch, logs=None):
        # Generate the image from noise
        g_img = self.model.generator(self.noise)
        # Denormalize the image
        g_img = (g_img * 255).numpy().astype(np.uint8)

        for i in range(g_img.shape[0]):
            # Convert generated images to PIL Image format
            img = Image.fromarray(g_img[i])
            # Save the image to the local folder
            img.save(f'generated_images/image_epoch_{epoch+1}_img_{i+1}.png')

    def on_train_end(self, logs=None):
        self.model.generator.save('DCGEN.h5')

# %%
# Training DCGAN on Image Dataset for 40 Epochs

epochs = 200
lr_g =0.0003
lr_d = 0.0001
beta = 0.5
latent_dim = 300

dcgan = DCGAN(generator=generator, discriminator=discriminator, latent_dim = latent_dim )
dcgan.compile(g_optimizer = Adam (learning_rate= lr_g, beta_1= beta), d_optimizer= Adam (learning_rate = lr_g , beta_1= beta), loss_fn = BinaryCrossentropy())

# Fit the model and save the history
history = dcgan.fit(train_generator, epochs=epochs, callbacks=[DCGANMonitor()])
# Out:
# Epoch 1/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 19s 160ms/step - d_loss: 0.6033 - g_loss: 1.2465
# Epoch 2/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 1.8426 - g_loss: 2.6303
# Epoch 3/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.7333 - g_loss: 1.6200
# Epoch 4/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - d_loss: 0.2839 - g_loss: 1.5619
# Epoch 5/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - d_loss: 0.3957 - g_loss: 1.6307
# Epoch 6/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - d_loss: 0.3247 - g_loss: 2.2330
# Epoch 7/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.4730 - g_loss: 1.8228
# Epoch 8/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.6853 - g_loss: 2.1443
# Epoch 9/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.5057 - g_loss: 2.4930
# Epoch 10/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3901 - g_loss: 2.2804
# Epoch 11/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - d_loss: 0.5321 - g_loss: 1.9948
# Epoch 12/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.5714 - g_loss: 1.7937
# Epoch 13/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.4721 - g_loss: 1.8432
# Epoch 14/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4183 - g_loss: 1.7817
# Epoch 15/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.6975 - g_loss: 2.4742
# Epoch 16/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - d_loss: 0.4314 - g_loss: 1.9708
# Epoch 17/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4694 - g_loss: 2.1543
# Epoch 18/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4183 - g_loss: 2.0753
# Epoch 19/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4955 - g_loss: 1.6735
# Epoch 20/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4549 - g_loss: 2.1047
# Epoch 21/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - d_loss: 0.5016 - g_loss: 1.9840
# Epoch 22/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - d_loss: 0.4951 - g_loss: 1.6530
# Epoch 23/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.5042 - g_loss: 1.8211
# Epoch 24/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.5415 - g_loss: 1.6423
# Epoch 25/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.5675 - g_loss: 1.3835
# Epoch 26/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4779 - g_loss: 1.5313
# Epoch 27/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - d_loss: 0.5263 - g_loss: 1.8337
# Epoch 28/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - d_loss: 0.4549 - g_loss: 1.8598
# Epoch 29/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.4502 - g_loss: 2.0492
# Epoch 30/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.5050 - g_loss: 2.0073
# Epoch 31/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.5105 - g_loss: 1.9258
# Epoch 32/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4371 - g_loss: 2.0225
# Epoch 33/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - d_loss: 0.5299 - g_loss: 1.8962
# Epoch 34/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - d_loss: 0.4551 - g_loss: 1.5912
# Epoch 35/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.5427 - g_loss: 2.0629
# Epoch 36/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.4631 - g_loss: 1.6302
# Epoch 37/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4043 - g_loss: 1.8102
# Epoch 38/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - d_loss: 0.5359 - g_loss: 1.9570
# Epoch 39/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - d_loss: 0.4501 - g_loss: 1.9862
# Epoch 40/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - d_loss: 0.4345 - g_loss: 2.2262
# Epoch 41/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3956 - g_loss: 2.2190
# Epoch 42/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3774 - g_loss: 2.0017
# Epoch 43/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.4003 - g_loss: 2.3442
# Epoch 44/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - d_loss: 0.3993 - g_loss: 1.9209
# Epoch 45/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - d_loss: 0.4641 - g_loss: 2.0033
# Epoch 46/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4379 - g_loss: 1.9607
# Epoch 47/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3108 - g_loss: 2.3471
# Epoch 48/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4361 - g_loss: 2.3422
# Epoch 49/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3877 - g_loss: 2.0734
# Epoch 50/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - d_loss: 0.4715 - g_loss: 2.0644
# Epoch 51/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - d_loss: 0.3342 - g_loss: 2.1397
# Epoch 52/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4480 - g_loss: 2.4257
# Epoch 53/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3902 - g_loss: 2.4083
# Epoch 54/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4384 - g_loss: 1.9726
# Epoch 55/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4443 - g_loss: 1.7224
# Epoch 56/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - d_loss: 0.5534 - g_loss: 2.3445
# Epoch 57/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.3770 - g_loss: 2.0872
# Epoch 58/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4109 - g_loss: 2.1446
# Epoch 59/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2785 - g_loss: 1.9715
# Epoch 60/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.3525 - g_loss: 2.5618
# Epoch 61/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3458 - g_loss: 2.4092
# Epoch 62/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - d_loss: 0.3298 - g_loss: 2.2714
# Epoch 63/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3699 - g_loss: 2.6488
# Epoch 64/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3216 - g_loss: 2.1573
# Epoch 65/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.4284 - g_loss: 2.5775
# Epoch 66/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2812 - g_loss: 1.7919
# Epoch 67/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.4351 - g_loss: 2.3759
# Epoch 68/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - d_loss: 0.3430 - g_loss: 2.1103
# Epoch 69/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - d_loss: 0.4656 - g_loss: 1.9838
# Epoch 70/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.4311 - g_loss: 2.2568
# Epoch 71/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.2982 - g_loss: 2.1152
# Epoch 72/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3145 - g_loss: 2.4693
# Epoch 73/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3334 - g_loss: 2.4183
# Epoch 74/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - d_loss: 0.2932 - g_loss: 2.5299
# Epoch 75/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1848 - g_loss: 2.8125
# Epoch 76/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.3601 - g_loss: 2.7965
# Epoch 77/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3363 - g_loss: 2.5266
# Epoch 78/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3164 - g_loss: 2.5112
# Epoch 79/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2033 - g_loss: 2.3929
# Epoch 80/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3605 - g_loss: 2.4042
# Epoch 81/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - d_loss: 0.2757 - g_loss: 2.4452
# Epoch 82/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.3709 - g_loss: 2.9802
# Epoch 83/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.7338 - g_loss: 2.6525
# Epoch 84/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1872 - g_loss: 2.7126
# Epoch 85/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4144 - g_loss: 2.3314
# Epoch 86/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2661 - g_loss: 2.7832
# Epoch 87/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - d_loss: 0.2911 - g_loss: 2.6193
# Epoch 88/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - d_loss: 0.3853 - g_loss: 3.1421
# Epoch 89/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2342 - g_loss: 2.3226
# Epoch 90/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.1968 - g_loss: 2.0255
# Epoch 91/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.1891 - g_loss: 2.6303
# Epoch 92/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3076 - g_loss: 2.7224
# Epoch 93/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - d_loss: 0.4419 - g_loss: 2.2616
# Epoch 94/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - d_loss: 0.2889 - g_loss: 2.5307
# Epoch 95/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3160 - g_loss: 2.4782
# Epoch 96/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2766 - g_loss: 2.3587
# Epoch 97/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.2182 - g_loss: 2.6210
# Epoch 98/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - d_loss: 0.3776 - g_loss: 2.6549
# Epoch 99/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - d_loss: 0.3012 - g_loss: 2.5377
# Epoch 100/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - d_loss: 0.2760 - g_loss: 2.3207
# Epoch 101/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2207 - g_loss: 2.3745
# Epoch 102/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.2308 - g_loss: 2.8430
# Epoch 103/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - d_loss: 0.3141 - g_loss: 2.3788
# Epoch 104/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - d_loss: 0.1870 - g_loss: 2.4391
# Epoch 105/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1007 - g_loss: 2.8888
# Epoch 106/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3794 - g_loss: 2.6498
# Epoch 107/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3162 - g_loss: 2.4356
# Epoch 108/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.5855 - g_loss: 3.3635
# Epoch 109/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1511 - g_loss: 2.8736
# Epoch 110/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - d_loss: 0.1459 - g_loss: 3.1884
# Epoch 111/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - d_loss: 0.3514 - g_loss: 2.8515
# Epoch 112/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4288 - g_loss: 2.3740
# Epoch 113/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4702 - g_loss: 1.4458
# Epoch 114/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.2860 - g_loss: 2.1930
# Epoch 115/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3450 - g_loss: 2.8497
# Epoch 116/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - d_loss: 0.3175 - g_loss: 1.9136
# Epoch 117/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - d_loss: 0.2861 - g_loss: 1.9968
# Epoch 118/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - d_loss: 0.0991 - g_loss: 2.5452
# Epoch 119/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.0899 - g_loss: 3.8453
# Epoch 120/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.1341 - g_loss: 2.9862
# Epoch 121/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - d_loss: 0.1021 - g_loss: 3.1508
# Epoch 122/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - d_loss: 0.0908 - g_loss: 2.7729
# Epoch 123/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3889 - g_loss: 3.6748
# Epoch 124/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.3388 - g_loss: 2.2361
# Epoch 125/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.1155 - g_loss: 2.9480
# Epoch 126/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.1874 - g_loss: 3.5530
# Epoch 127/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - d_loss: 0.2662 - g_loss: 1.8828
# Epoch 128/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - d_loss: 0.2961 - g_loss: 3.0545
# Epoch 129/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2040 - g_loss: 2.7458
# Epoch 130/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.1096 - g_loss: 3.1126
# Epoch 131/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2250 - g_loss: 3.3960
# Epoch 132/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.1900 - g_loss: 3.2725
# Epoch 133/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - d_loss: 0.4586 - g_loss: 2.9328
# Epoch 134/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - d_loss: 0.1820 - g_loss: 2.7359
# Epoch 135/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - d_loss: 0.3232 - g_loss: 2.7062
# Epoch 136/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3401 - g_loss: 2.2389
# Epoch 137/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2242 - g_loss: 2.2949
# Epoch 138/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3420 - g_loss: 2.8430
# Epoch 139/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2396 - g_loss: 2.3803
# Epoch 140/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - d_loss: 0.3060 - g_loss: 2.1318
# Epoch 141/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - d_loss: 0.3631 - g_loss: 2.6842
# Epoch 142/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1217 - g_loss: 2.5521
# Epoch 143/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.2767 - g_loss: 3.7956
# Epoch 144/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3510 - g_loss: 2.9470
# Epoch 145/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - d_loss: 0.2351 - g_loss: 3.0974
# Epoch 146/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - d_loss: 0.2463 - g_loss: 2.2695
# Epoch 147/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2458 - g_loss: 2.5073
# Epoch 148/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1529 - g_loss: 3.2061
# Epoch 149/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1869 - g_loss: 4.0610
# Epoch 150/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3212 - g_loss: 2.8748
# Epoch 151/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2859 - g_loss: 3.1149
# Epoch 152/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - d_loss: 0.1774 - g_loss: 2.9304
# Epoch 153/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1839 - g_loss: 2.7389
# Epoch 154/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1462 - g_loss: 3.7428
# Epoch 155/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.4419 - g_loss: 2.0718
# Epoch 156/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1331 - g_loss: 3.4008
# Epoch 157/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.7062 - g_loss: 3.3551
# Epoch 158/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.0874 - g_loss: 2.7259
# Epoch 159/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - d_loss: 0.3827 - g_loss: 3.5215
# Epoch 160/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - d_loss: 0.1771 - g_loss: 2.4337
# Epoch 161/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1786 - g_loss: 3.0122
# Epoch 162/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.3897 - g_loss: 3.3640
# Epoch 163/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.2140 - g_loss: 2.8719
# Epoch 164/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - d_loss: 0.2330 - g_loss: 2.9081
# Epoch 165/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3240 - g_loss: 3.6785
# Epoch 166/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.0976 - g_loss: 2.8421
# Epoch 167/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1990 - g_loss: 3.3407
# Epoch 168/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.4062 - g_loss: 3.4886
# Epoch 169/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - d_loss: 0.1485 - g_loss: 3.1284
# Epoch 170/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - d_loss: 0.1965 - g_loss: 3.0231
# Epoch 171/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - d_loss: 0.0996 - g_loss: 3.2850
# Epoch 172/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.3541 - g_loss: 4.2065
# Epoch 173/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.2585 - g_loss: 2.2631
# Epoch 174/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - d_loss: 0.9426 - g_loss: 2.9995
# Epoch 175/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - d_loss: 0.2074 - g_loss: 2.1543
# Epoch 176/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - d_loss: 0.1912 - g_loss: 3.0752
# Epoch 177/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.2855 - g_loss: 3.7739
# Epoch 178/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.2799 - g_loss: 3.3606
# Epoch 179/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - d_loss: 0.2110 - g_loss: 2.7820
# Epoch 180/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - d_loss: -0.0229 - g_loss: 3.1553
# Epoch 181/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - d_loss: 0.2826 - g_loss: 2.1092
# Epoch 182/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.0716 - g_loss: 2.5741
# Epoch 183/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.2074 - g_loss: 2.7734
# Epoch 184/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1815 - g_loss: 3.7631
# Epoch 185/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.1288 - g_loss: 3.3123
# Epoch 186/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - d_loss: 0.7089 - g_loss: 3.5478
# Epoch 187/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - d_loss: 0.2233 - g_loss: 2.3937
# Epoch 188/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.0491 - g_loss: 2.7213
# Epoch 189/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.5374 - g_loss: 4.6153
# Epoch 190/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3716 - g_loss: 3.2668
# Epoch 191/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: -0.0547 - g_loss: 3.3077
# Epoch 192/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - d_loss: 0.1995 - g_loss: 3.3728
# Epoch 193/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - d_loss: -0.0147 - g_loss: 4.2958
# Epoch 194/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - d_loss: -0.0457 - g_loss: 4.5206
# Epoch 195/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2174 - g_loss: 3.6938
# Epoch 196/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.3716 - g_loss: 1.9982
# Epoch 197/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.1242 - g_loss: 2.2958
# Epoch 198/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.0941 - g_loss: 3.6833
# Epoch 199/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - d_loss: 0.0399 - g_loss: 3.1802
# Epoch 200/200
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - d_loss: -0.0028 - g_loss: 3.1660
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os

plt.figure(figsize=(10, 10))

# Create a directory to save generated images if it doesn't exist
if not os.path.exists('generated_images'):
    os.makedirs('generated_images')

for i in range(36):
    plt.subplot(6, 6, i + 1)
    # Generate random noise for each image
    noise = tf.random.normal([1, 300])
    mg = dcgan.generator(noise)
    # Denormalize
    mg = (mg * 255).numpy().astype(np.uint8)

    image = Image.fromarray(mg[0])
    # Save the image to the local folder
    image.save(f'generated_images/image_{i+1}.png')

    plt.imshow(image)
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

# Function to create a figure for the losses
def create_loss_figure(d_loss_values, g_loss_values):
    plt.figure(figsize=(10, 6))
    plt.plot(d_loss_values, label='Discriminator Loss')
    plt.plot(g_loss_values, label='Generator Loss')
    plt.title('Generator and Discriminator Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Access the loss values from the history
d_loss_values = history.history['d_loss']
g_loss_values = history.history['g_loss']

# Call the create_loss_figure function with the loss values
create_loss_figure(d_loss_values, g_loss_values)

# %%
# !zip -r generated_images.zip generated_images/
from google.colab import files
files.download('generated_images.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: generated_images/image_epoch_47_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_69_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_89_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_17.png (stored 0%)
#   adding: generated_images/image_22.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_108_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_150_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_9.png (deflated 0%)
#   adding: generated_images/image_25.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_14.png (stored 0%)
#   adding: generated_images/image_32.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_14.png (deflated 0%)
#   adding: generated_images/image_epoch_42_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_177_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_4.png (stored 0%)
#   adding: generated_images/image_33.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_15.png (stored 0%)
#   adding: generated_images/image_14.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_100_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_18.png (stored 0%)
# ...
#   adding: generated_images/image_epoch_25_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_25_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_145_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_98_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_14.png (stored 0%)
#   adding: generated_images/image_30.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_61_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_15.png (deflated 0%)
#   adding: generated_images/image_epoch_123_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_96_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_176_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_120_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_144_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_65_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_19.png (stored 0%)
#   adding: generated_images/image_15.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_119_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_137_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_17.png (stored 0%)
