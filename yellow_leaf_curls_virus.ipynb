# %% [markdown]
# <a href="https://colab.research.google.com/github/bvsvarshini/Tomato-Leaves-Image-Generation-using-DCGAN/blob/main/yellow_leaf_curls_virus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import requirement libraries and tools
from tensorflow import keras
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style= "darkgrid", color_codes = True)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Conv2DTranspose, Reshape, BatchNormalization, Dropout, Input, ReLU, LeakyReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from PIL import Image

import warnings
warnings.filterwarnings('ignore')

# %%
import zipfile
import os

# Path to the uploaded zip file
zip_path = '/content/yellow.zip'
# Directory where the zip will be extracted
extraction_path = '/content/yellow/'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

# Verify extraction
print("Files extracted:")
print(os.listdir(extraction_path))
# Out:
# Files extracted:
# ['yellow']

# %%
data_dir = extraction_path

# Example: List files in the data_dir
import os
print(os.listdir(data_dir))
# Out:
# ['yellow']

# %%
img_width, img_height = 256, 256
batchsize = 32

train = keras. utils.image_dataset_from_directory(
    directory='yellow',
    batch_size = batchsize,
    image_size = (img_width, img_height))
# Out:
# Found 1590 files belonging to 1 classes.

# %%
import tensorflow as tf

# Define the path to the extracted images
data_dir = extraction_path

# Load the dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    image_size=(img_width, img_height),
    batch_size=batchsize,
    label_mode=None  # or 'int'/'categorical' depending on your labels
)
# Out:
# Found 1590 files.

# %%
data_iterator = train.as_numpy_iterator()
batch = data_iterator.next()
fig, ax = plt.subplots(ncols=4, figsize=(10,10))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
# Generating Augmented Batches of Images using ImageDataGenerator
DIR = 'yellow' #path

# Create an ImageDataGenerator object with data augmentation options for image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip = True)

train_generator = train_datagen.flow_from_directory(
        DIR,
        target_size = (64, 64),
        batch_size = batchsize,
        class_mode = None)

#train_generator[0]
# Out:
# Found 1590 images belonging to 1 classes.

# %%
from tensorflow.keras.layers import Conv2DTranspose, Dense, Reshape
from tensorflow.keras.models import Sequential
import tensorflow.keras as keras

KI = keras.initializers.RandomNormal(mean=0.0, stddev=0.02)
input_dim = 300

def Generator_Model():
    Generator = Sequential()

    # Random noise
    Generator.add(Dense(8 * 8 * 512, input_dim=input_dim))
    Generator.add(keras.layers.Activation('relu'))  # Use 'relu' as a string
    # Convert 1D to 3D
    Generator.add(Reshape((8, 8, 512)))
    # Upsample
    Generator.add(Conv2DTranspose(256, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2DTranspose(64, (4, 4), strides=(2, 2), padding='same', kernel_initializer=KI, activation='relu'))
    Generator.add(Conv2D(3, (4, 4), padding='same', activation='sigmoid'))

    return Generator

generator = Generator_Model()
generator.summary()
# Visualize Layers of generator
keras.utils.plot_model(generator, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32768)               │       9,863,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 16, 16, 256)         │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 32, 32, 128)         │         524,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 64, 64, 64)          │         131,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 64, 64, 3)           │           3,075 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,619,203 (48.14 MB)
#  Trainable params: 12,619,203 (48.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, LeakyReLU
from tensorflow.keras.models import Sequential

def Discriminator_Model():
    input_shape = (64, 64, 3)

    # Create a Sequential model
    discriminator = Sequential()
    discriminator.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(128, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Conv2D(256, kernel_size=(3, 3)))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(MaxPooling2D(pool_size=(2, 2)))
    discriminator.add(Flatten())
    discriminator.add(Dense(256))
    discriminator.add(LeakyReLU(alpha=0.2))  # Use LeakyReLU with an alpha parameter
    discriminator.add(Dense(1, activation='sigmoid'))

    return discriminator

# Training The CNN
discriminator = Discriminator_Model()
discriminator.summary()
# Visualize Layers of discriminator
import tensorflow.keras as keras
keras.utils.plot_model(discriminator, show_shapes=True)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)                    │ (None, 62, 62, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 62, 62, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 29, 29, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 29, 29, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 12, 12, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │       2,359,552 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,730,625 (10.42 MB)
#  Trainable params: 2,730,625 (10.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# DCGAN Model Training Step with Discriminator and Generator

class DCGAN(keras.Model):
    def __init__(self, generator, discriminator, latent_dim = input_dim):
        super().__init__()
        self.generator = generator
        self.discriminator = discriminator
        self.latent_dim = latent_dim
        self.g_loss_metric = keras.metrics.Mean(name='g_loss')
        self.d_loss_metric = keras.metrics.Mean(name='d_loss')

    @property
    def metrics(self):
        return [self.g_loss_metric, self.d_loss_metric]

    def compile(self, g_optimizer, d_optimizer, loss_fn):
        super(DCGAN, self).compile()
        self.g_optimizer = g_optimizer
        self.d_optimizer = d_optimizer
        self.loss_fn = loss_fn

    def train_step(self, real_images):
        # get batch size from the data
        batch_size = tf.shape(real_images)[0]
        # generate random noise
        random_noise = tf.random.normal(shape=(batch_size, self.latent_dim))

        # train the discriminator with real (1) and fake (0) images
        with tf.GradientTape() as tape:
            # compute loss on real images
            pred_real = self.discriminator(real_images, training=True)
            # generate real image labels
            real_labels = tf.ones((batch_size, 1))
            # label smoothing
            real_labels += 0.05 * tf.random.uniform(tf.shape(real_labels))
            d_loss_real = self.loss_fn(real_labels, pred_real)

            # compute loss on fake images
            fake_images = self.generator(random_noise)
            pred_fake = self.discriminator(fake_images, training=True)
            # generate fake labels
            fake_labels = tf.zeros((batch_size, 1))
            d_loss_fake = self.loss_fn(fake_labels, pred_fake)

            # total discriminator loss
            d_loss = (d_loss_real + d_loss_fake) / 2
        # compute discriminator gradients
        gradients = tape.gradient(d_loss, self.discriminator.trainable_variables)
        # update the gradients
        self.d_optimizer.apply_gradients(zip(gradients, self.discriminator.trainable_variables))


        # train the generator model
        labels = tf.ones((batch_size, 1))
        # generator want discriminator to think that fake images are real
        with tf.GradientTape() as tape:
            # generate fake images from generator
            fake_images = self.generator(random_noise, training=True)
            # classify images as real or fake
            pred_fake = self.discriminator(fake_images, training=True)
            # compute loss
            g_loss = self.loss_fn(labels, pred_fake)

        # compute gradients
        gradients = tape.gradient(g_loss, self.generator.trainable_variables)
        # update the gradients
        self.g_optimizer.apply_gradients(zip(gradients, self.generator.trainable_variables))

        # update states for both models
        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {'d_loss': self.d_loss_metric.result(), 'g_loss': self.g_loss_metric.result()}

# %%
import os

class DCGANMonitor(keras.callbacks.Callback):
    def __init__(self, num_imgs=25, latent_dim = input_dim):
        self.num_imgs = num_imgs
        self.latent_dim = latent_dim
        # Create random noise for generating images
        self.noise = tf.random.normal([25, latent_dim])
        # Create a directory to save generated images if it doesn't exist
        if not os.path.exists('generated_images'):
            os.makedirs('generated_images')

    def on_epoch_end(self, epoch, logs=None):
        # Generate the image from noise
        g_img = self.model.generator(self.noise)
        # Denormalize the image
        g_img = (g_img * 255).numpy().astype(np.uint8)

        for i in range(g_img.shape[0]):
            # Convert generated images to PIL Image format
            img = Image.fromarray(g_img[i])
            # Save the image to the local folder
            img.save(f'generated_images/image_epoch_{epoch+1}_img_{i+1}.png')

    def on_train_end(self, logs=None):
        self.model.generator.save('DCGEN.h5')

# %%
# Training DCGAN on Image Dataset for 40 Epochs

epochs = 200
lr_g =0.0003
lr_d = 0.0001
beta = 0.5
latent_dim = 300

dcgan = DCGAN(generator=generator, discriminator=discriminator, latent_dim = latent_dim )
dcgan.compile(g_optimizer = Adam (learning_rate= lr_g, beta_1= beta), d_optimizer= Adam (learning_rate = lr_g , beta_1= beta), loss_fn = BinaryCrossentropy())

# Fit the model and save the history
history = dcgan.fit(train_generator, epochs=epochs, callbacks=[DCGANMonitor()])
# Out:
# Epoch 1/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - d_loss: 0.5497 - g_loss: 1.4020
# Epoch 2/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 8s 30ms/step - d_loss: 0.7973 - g_loss: 2.1989
# Epoch 3/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - d_loss: 0.3574 - g_loss: 2.3596
# Epoch 4/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - d_loss: 0.6203 - g_loss: 1.4066
# Epoch 5/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4484 - g_loss: 1.6525
# Epoch 6/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3509 - g_loss: 2.4150
# Epoch 7/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.2298 - g_loss: 2.4035
# Epoch 8/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.3341 - g_loss: 2.9214
# Epoch 9/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - d_loss: 0.2819 - g_loss: 2.8155
# Epoch 10/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.3424 - g_loss: 2.3266
# Epoch 11/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5259 - g_loss: 2.0178
# Epoch 12/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - d_loss: 0.4274 - g_loss: 2.2805
# Epoch 13/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4316 - g_loss: 2.3216
# Epoch 14/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.6516 - g_loss: 1.8692
# Epoch 15/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.4598 - g_loss: 2.2513
# Epoch 16/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - d_loss: 0.4230 - g_loss: 2.0658
# Epoch 17/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5205 - g_loss: 1.5630
# Epoch 18/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5107 - g_loss: 1.7612
# Epoch 19/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4272 - g_loss: 1.8058
# Epoch 20/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3703 - g_loss: 2.2790
# Epoch 21/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - d_loss: 0.5380 - g_loss: 2.2986
# Epoch 22/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - d_loss: 0.5167 - g_loss: 1.7546
# Epoch 23/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4962 - g_loss: 1.9162
# Epoch 24/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4868 - g_loss: 1.5406
# Epoch 25/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.6863 - g_loss: 2.0918
# Epoch 26/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - d_loss: 0.4718 - g_loss: 1.4735
# Epoch 27/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5134 - g_loss: 1.7183
# Epoch 28/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - d_loss: 0.4678 - g_loss: 1.6887
# Epoch 29/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4740 - g_loss: 2.3460
# Epoch 30/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - d_loss: 0.5190 - g_loss: 1.5266
# Epoch 31/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.4177 - g_loss: 1.7267
# Epoch 32/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.5517 - g_loss: 1.9864
# Epoch 33/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - d_loss: 0.4440 - g_loss: 1.9271
# Epoch 34/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - d_loss: 0.5759 - g_loss: 2.2243
# Epoch 35/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4967 - g_loss: 1.6171
# Epoch 36/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4944 - g_loss: 2.2410
# Epoch 37/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4550 - g_loss: 1.7278
# Epoch 38/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.4483 - g_loss: 2.0171
# Epoch 39/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4539 - g_loss: 2.2727
# Epoch 40/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - d_loss: 0.4325 - g_loss: 1.9210
# Epoch 41/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step
200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.4408 - g_loss: 1.8425
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - d_loss: 0.3768 - g_loss: 2.3893
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3203 - g_loss: 2.2917
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.4110 - g_loss: 2.4632
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.2674 - g_loss: 2.7012
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4687 - g_loss: 2.2170
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - d_loss: 0.4271 - g_loss: 2.3441
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - d_loss: 0.3116 - g_loss: 2.5257
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3727 - g_loss: 2.7669
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.5100 - g_loss: 1.5274
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4398 - g_loss: 1.8397
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.3534 - g_loss: 2.3801
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.3672 - g_loss: 2.2571
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - d_loss: 0.2717 - g_loss: 2.8245
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.4896 - g_loss: 2.6856
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3231 - g_loss: 2.3422
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3827 - g_loss: 2.3592
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4146 - g_loss: 2.6854
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3416 - g_loss: 2.7902
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - d_loss: 0.3031 - g_loss: 2.5200
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3703 - g_loss: 2.6804
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2818 - g_loss: 2.4407
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3130 - g_loss: 2.2359
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3501 - g_loss: 2.0763
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2346 - g_loss: 2.6471
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - d_loss: 0.3109 - g_loss: 2.9828
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - d_loss: 0.3895 - g_loss: 2.7785
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.2960 - g_loss: 2.5024
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3010 - g_loss: 2.9870
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - d_loss: 0.4065 - g_loss: 2.1315
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2256 - g_loss: 2.3246
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - d_loss: 0.3651 - g_loss: 2.1925
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - d_loss: 0.3934 - g_loss: 2.3876
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5538 - g_loss: 2.5887
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3548 - g_loss: 2.2181
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.3998 - g_loss: 2.4922
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3133 - g_loss: 2.0428
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - d_loss: 0.2491 - g_loss: 2.6301
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - d_loss: 0.3046 - g_loss: 2.6853
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2330 - g_loss: 2.4857
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4492 - g_loss: 2.3423
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - d_loss: 0.2200 - g_loss: 2.7069
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3618 - g_loss: 1.9531
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.2927 - g_loss: 2.1397
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - d_loss: 0.3068 - g_loss: 2.4886
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - d_loss: 0.2412 - g_loss: 2.0807
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.3968 - g_loss: 2.8800
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - d_loss: 0.2339 - g_loss: 2.2270
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2878 - g_loss: 2.5761
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - d_loss: 0.3576 - g_loss: 2.6778
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - d_loss: 0.4721 - g_loss: 2.4497
# Epoch 167/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3364 - g_loss: 2.2905
# Epoch 168/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - d_loss: 0.2151 - g_loss: 2.7037
# Epoch 169/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5456 - g_loss: 2.8464
# Epoch 170/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - d_loss: 0.3337 - g_loss: 2.2750
# Epoch 171/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - d_loss: 0.3611 - g_loss: 2.9210
# Epoch 172/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - d_loss: 0.3435 - g_loss: 2.5807
# Epoch 173/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.4188 - g_loss: 2.8563
# Epoch 174/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3143 - g_loss: 2.7735
# Epoch 175/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.5824 - g_loss: 2.7829
# Epoch 176/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2890 - g_loss: 2.4888
# Epoch 177/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3977 - g_loss: 2.7945
# Epoch 178/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - d_loss: 0.4564 - g_loss: 2.4379
# Epoch 179/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - d_loss: 0.3120 - g_loss: 2.3697
# Epoch 180/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2915 - g_loss: 2.4933
# Epoch 181/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.4462 - g_loss: 3.2538
# Epoch 182/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.2918 - g_loss: 2.7411
# Epoch 183/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3410 - g_loss: 2.3926
# Epoch 184/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - d_loss: 0.3254 - g_loss: 2.4607
# Epoch 185/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - d_loss: 0.4161 - g_loss: 2.3464
# Epoch 186/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.3355 - g_loss: 2.7081
# Epoch 187/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.3189 - g_loss: 2.2720
# Epoch 188/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - d_loss: 0.4304 - g_loss: 1.9597
# Epoch 189/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - d_loss: 0.2925 - g_loss: 2.6639
# Epoch 190/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3277 - g_loss: 2.6531
# Epoch 191/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - d_loss: 0.3262 - g_loss: 2.2956
# Epoch 192/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - d_loss: 0.2851 - g_loss: 2.5959
# Epoch 193/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - d_loss: 0.2897 - g_loss: 2.7043
# Epoch 194/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - d_loss: 0.3851 - g_loss: 2.9112
# Epoch 195/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - d_loss: 0.3517 - g_loss: 2.4911
# Epoch 196/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - d_loss: 0.3208 - g_loss: 2.2988
# Epoch 197/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - d_loss: 0.2781 - g_loss: 2.8619
# Epoch 198/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - d_loss: 0.4391 - g_loss: 3.2154
# Epoch 199/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.2715 - g_loss: 3.0316
# Epoch 200/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - d_loss: 0.3654 - g_loss: 3.7935
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os

plt.figure(figsize=(10, 10))

# Create a directory to save generated images if it doesn't exist
if not os.path.exists('generated_images'):
    os.makedirs('generated_images')

for i in range(36):
    plt.subplot(6, 6, i + 1)
    # Generate random noise for each image
    noise = tf.random.normal([1, 300])
    mg = dcgan.generator(noise)
    # Denormalize
    mg = (mg * 255).numpy().astype(np.uint8)

    image = Image.fromarray(mg[0])
    # Save the image to the local folder
    image.save(f'generated_images/image_{i+1}.png')

    plt.imshow(image)
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

# Function to create a figure for the losses
def create_loss_figure(d_loss_values, g_loss_values):
    plt.figure(figsize=(10, 6))
    plt.plot(d_loss_values, label='Discriminator Loss')
    plt.plot(g_loss_values, label='Generator Loss')
    plt.title('Generator and Discriminator Losses')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Access the loss values from the history
d_loss_values = history.history['d_loss']
g_loss_values = history.history['g_loss']

# Call the create_loss_figure function with the loss values
create_loss_figure(d_loss_values, g_loss_values)

# %%
# !zip -r generated_images.zip generated_images/
from google.colab import files
files.download('generated_images.zip')
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: generated_images/image_epoch_194_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_1.png (stored 0%)
#   adding: generated_images/image_5.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_134_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_123_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_117_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_56_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_107_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_59_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_196_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_84_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_67_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_17.png (stored 0%)
#   adding: generated_images/image_8.png (stored 0%)
#   adding: generated_images/image_epoch_4_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_28_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_93_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_14_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_33_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_60_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_88_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_103_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_132_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_27_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_48_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_131_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_191_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_151_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_89_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_32_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_156_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_82_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_76_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_124_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_52_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_92_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_68_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_105_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_17_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_136_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_11_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_114_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_109_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_130_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_115_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_171_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_162_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_71_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_78_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_47_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_143_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_94_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_81_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_174_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_86_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_23_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_195_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_165_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_185_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_64_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_44_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_180_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_141_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_18_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_149_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_85_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_53_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_95_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_122_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_118_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_127_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_35_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_42_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_73_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_112_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_13_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_142_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_181_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_8_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_101_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_190_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_104_img_11.png (stored 0%)
#   adding: generated_images/image_30.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_89_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_155_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_200_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_9_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_175_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_164_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_147_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_3_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_99_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_74_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_125_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_128_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_20_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_198_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_133_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_157_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_139_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_172_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_2_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_63_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_79_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_148_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_126_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_36_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_19_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_161_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_21_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_58_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_183_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_16_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_26_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_121_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_169_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_178_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_102_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_40_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_72_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_158_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_43_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_49_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_153_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_77_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_5_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_1_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_163_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_194_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_38_img_4.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_187_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_197_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_57_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_55_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_168_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_22.png (stored 0%)
#   adding: generated_images/image_epoch_186_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_29_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_199_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_193_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_10_img_5.png (stored 0%)
#   adding: generated_images/image_epoch_50_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_34_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_75_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_188_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_110_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_111_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_152_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_140_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_173_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_154_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_5.png (stored 0%)
#   adding: generated_images/image_35.png (stored 0%)
#   adding: generated_images/image_epoch_192_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_45_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_70_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_54_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_135_img_2.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_113_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_167_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_51_img_18.png (stored 0%)
#   adding: generated_images/image_epoch_179_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_83_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_6_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_15_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_182_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_129_img_9.png (stored 0%)
#   adding: generated_images/image_epoch_91_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_39_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_166_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_7.png (stored 0%)
#   adding: generated_images/image_epoch_41_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_22_img_20.png (stored 0%)
#   adding: generated_images/image_epoch_66_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_170_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_80_img_12.png (stored 0%)
#   adding: generated_images/image_epoch_7_img_3.png (stored 0%)
#   adding: generated_images/image_epoch_46_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_189_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_184_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_24_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_116_img_8.png (stored 0%)
#   adding: generated_images/image_epoch_90_img_6.png (stored 0%)
#   adding: generated_images/image_epoch_62_img_24.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_11.png (stored 0%)
#   adding: generated_images/image_epoch_146_img_1.png (stored 0%)
#   adding: generated_images/image_epoch_160_img_21.png (stored 0%)
#   adding: generated_images/image_epoch_106_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_30_img_16.png (stored 0%)
#   adding: generated_images/image_epoch_97_img_19.png (stored 0%)
#   adding: generated_images/image_epoch_87_img_23.png (stored 0%)
#   adding: generated_images/image_epoch_31_img_14.png (stored 0%)
#   adding: generated_images/image_epoch_12_img_17.png (stored 0%)
#   adding: generated_images/image_epoch_89_img_10.png (stored 0%)
#   adding: generated_images/image_epoch_138_img_15.png (stored 0%)
#   adding: generated_images/image_epoch_159_img_25.png (stored 0%)
#   adding: generated_images/image_epoch_37_img_13.png (stored 0%)
#   adding: generated_images/image_epoch_131_img